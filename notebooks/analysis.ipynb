# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import fiona
from shapely.geometry import Polygon
# Create a sample GeoDataFrame with polygon geometries
gdb_path = '/Volumes/HOLMES/NITENI/github/nb_001_batam_atlas/data/boundaries/KOTA BATAM/RBI50K_KOTABATAM_KUGI50_20221231.gdb'
fiona.listlayers(gdb_path)  # List layers in the shapefile
# Out:
# ['HERBADANRUMPUT_AR_50K',
#  'HUTANLAHANRENDAH_AR_50K',
#  'HUTANLAHANTINGGI_AR_50K',
#  'HUTANMANGROVE_AR_50K',
#  'LADANG_AR_50K',
#  'PERKEBUNAN_AR_50K',
#  'SEMAKBELUKAR_AR_50K',
#  'TANAMANCAMPUR_AR_50K',
#  'PANCARTV_PT_50K',
#  'MENARATELEPON_PT_50K',
#  'KANTORTELEPON_PT_50K',
#  'KANTORPOS_PT_50K',
#  'KANTORPLN_PT_50K',
#  'KABELLISTRIK_LN_50K',
#  'GENLISTRIK_PT_50K',
#  'PERSAMPAHAN_PT_50K',
#  'PANCARRADIO_PT_50K',
#  'SUMURMINYAK_PT_50K',
#  'JEMBATAN_PT_50K',
#  'TONGGAKKM_PT_50K',
#  'DERMAGA_AR_50K',
#  'PELABUHAN_PT_50K',
#  'PELABUHAN_AR_50K',
#  'RUNWAY_AR_50K',
#  'DERMAGA_PT_50K',
#  'JALAN_AR_50K',
#  'TERMINALBUS_PT_50K',
#  'LIGHT_PT_50K',
#  'RUNWAY_LN_50K',
#  'JALAN_LN_50K',
#  'TOPONIMI_PT_50K',
#  'RUMAHSAKIT_PT_50K',
#  'SARANAIBADAH_PT_50K',
#  'NIAGA_PT_50K',
#  'CAGARBUDAYA_PT_50K',
#  'PERMUKIMAN_AR_50K',
#  'PUSKESMAS_PT_50K',
#  'PENDIDIKAN_PT_50K',
#  'PERUMAHAN_PT_50K',
#  'INDUSTRI_AR_50K',
#  'ARENAOLAHRAGA_AR_50K',
#  'PEMERINTAHAN_PT_50K',
#  'SPOTHEIGHT_PT_50K',
#  'KONTUR_LN_50K',
#  'SUNGAI_LN_50K',
#  'DANAU_AR_50K',
#  'EMPANG_AR_50K',
#  'PASIR_AR_50K',
#  'PESISIR_AR_50K',
#  'RAWA_AR_50K',
#  'SUNGAI_AR_50K',
#  'GARAM_AR_50K',
#  'LAUT_AR_50K_exBabel',
#  'GARISPANTAI_LN_50K',
#  'ADMINISTRASI_LN_KABKOTA',
#  'ADMINISTRASI_AR_KECAMATAN',
#  'ADMINISTRASI_AR_KABKOTA',
#  'ADMINISTRASI_AR_DESAKEL']

# %%
batas_kecamatan = gpd.read_file(
    gdb_path, layer='ADMINISTRASI_AR_KECAMATAN'
)
batas_kecamatan.columns
batas_kecamatan.plot()
plt.show()

batas_kecamatan.head()
len(batas_kecamatan)
batas_kecamatan.shape

batas_kecamatan.head(27)
# Out:
# /Users/holmes/miniforge3/envs/geo_env/lib/python3.10/site-packages/pyogrio/raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D MultiPolygon' is converted to 'MultiPolygon Z'
#   return ogr_read(
#                   NAMOBJ       FCODE REMARK  \
# 0           Bintan Utara  BA03070040   None
# 1           Teluk Bintan  BA03070040   None
# 2                Mantang  BA03070040   None
# 3       Seri Kuala Lobam  BA03070040   None
# 4                   Moro  BA03070040   None
# 5                   Buru  BA03070040   None
# 6           Kundur Utara  BA03070040   None
# 7                  Belat  BA03070040   None
# 8            Sugie Besar  BA03070040   None
# 9          Katang Bidare  BA03070040   None
# 10       Temiang Pesisir  BA03070040   None
# 11       Belakang Padang  BA03070040   None
# 12            Batu Ampar  BA03070040   None
# 13              Sekupang  BA03070040   None
# 14                Nongsa  BA03070040   None
# 15                Bulang  BA03070040   None
# 16            Lubuk Baja  BA03070040   None
# 17             Sei Beduk  BA03070040   None
# 18                Galang  BA03070040   None
# 19              Bengkong  BA03070040   None
# 20            Batam Kota  BA03070040   None
# 21              Sagulung  BA03070040   None
# 22              Batu Aji  BA03070040   None
# 23  Tanjung Pinang Barat  BA03070040   None
# 24  Tanjung Pinang Timur  BA03070040   None
# 25   Tanjung Pinang Kota  BA03070040   None
# 26         Bukit Bestari  BA03070040   None
#
#                                         METADATA     SRS_ID KDBBPS KDCBPS  \
# 0   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 1   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 2   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 3   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 4   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 5   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 6   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 7   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 8   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 9   TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 10  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 11  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 12  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 13  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 14  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 15  TASWIL1000020230928_DATA_BATAS_DESAKELURAHAN  SRGI 2013   None   None
# 19  MULTIPOLYGON Z (((104.02934 1.179 0, 104.02933...
# 20  MULTIPOLYGON Z (((104.07198 1.13765 0, 104.072...
# 21  MULTIPOLYGON Z (((104.02012 0.9712 0, 104.0200...
# 22  MULTIPOLYGON Z (((103.9182 1.02869 0, 103.9182...
# 23  MULTIPOLYGON Z (((104.45415 0.93169 0, 104.454...
# 24  MULTIPOLYGON Z (((104.49209 0.98018 0, 104.492...
# 25  MULTIPOLYGON Z (((104.5 0.99108 0, 104.5 0.990...
# 26  MULTIPOLYGON Z (((104.46569 0.9316 0, 104.4657...
#
# [27 rows x 27 columns]

# %%
batas_kecamatan = gpd.read_file(
    gdb_path, layer='ADMINISTRASI_AR_KECAMATAN'
)
bound_kecamatan = batas_kecamatan[
    batas_kecamatan['WADMKK'] == "Kota Batam"
].copy()

print(bound_kecamatan.shape)
print(bound_kecamatan.total_bounds)
print(bound_kecamatan.crs)

bound_kecamatan.to_crs("EPSG:4326", inplace=True)
bound_kecamatan.to_file(
    "../data/boundaries/KOTA BATAM/batas_kecamatan.geojson", 
    driver="GeoJSON"
)
# Out:
# /Users/holmes/miniforge3/envs/geo_env/lib/python3.10/site-packages/pyogrio/raw.py:198: UserWarning: Measured (M) geometry types are not supported. Original type 'Measured 3D MultiPolygon' is converted to 'MultiPolygon Z'
#   return ogr_read(
# (12, 27)
# [103.65141501   0.46257442 104.37116549   1.20639357]
# COMPD_CS["WGS 84 + EGM2008 height",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]],VERT_CS["EGM2008 height",VERT_DATUM["EGM2008 geoid",2005,AUTHORITY["EPSG","1027"]],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Gravity-related height",UP],AUTHORITY["EPSG","3855"]]]

# %%
bound_batam = gpd.read_file("../data/boundaries/KOTA BATAM/bound_batam.geojson")
bound_batam.plot()
plt.show()
print(bound_batam.crs)
print(bound_batam.total_bounds)

bound_kecamatan = gpd.read_file("../data/boundaries/KOTA BATAM/batas_kecamatan.geojson")
bound_kecamatan.plot()
plt.show()
print(bound_kecamatan.crs)
print(bound_kecamatan.total_bounds)
# Out:
# EPSG:4326
# [103.65141501   0.46257442 104.37116549   1.20639357]
# EPSG:4326
# [103.65141501   0.46257442 104.37116549   1.20639357]

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

batas_kecamatan = gpd.read_file('../data/boundaries/KOTA BATAM/batas_kecamatan.geojson')
batas_kecamatan.head(12)

btc = batas_kecamatan['NAMOBJ'] == 'Batam Kota'
batas_kecamatan[btc].plot()
plt.show()
